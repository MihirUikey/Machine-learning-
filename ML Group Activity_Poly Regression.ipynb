# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # <font color = 'Brown'>POLYNOMIAL REGRESSION</font>

# %%
#Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing the dataset
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Lab on ml/Ice-cream_Sales_Dataset.csv")
dataset
# Out:
#     Temperature  Sales_of_Ice_cream
# 0     10.000000           81.937967
# 1     11.428571           71.725826
# 2     12.857143           74.353116
# 3     14.285714           80.140477
# 4     15.714286           88.087910
# 5     17.142857           98.195414
# 6     18.571429          110.463989
# 7     20.000000          124.891635
# 8     21.428571          141.478352
# 9     22.857143          160.224140
# 10    24.285714          181.129999
# 11    25.714286          204.195929
# 12    27.142857          229.421930
# 13    28.571429          256.808002
# 14    30.000000          286.354145

# %%
#Extracting the values using iloc function from the above the dataset
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, -1].values
X,Y
# Out:
# (array([[10.      ],
#         [11.428571],
#         [12.857143],
#         [14.285714],
#         [15.714286],
#         [17.142857],
#         [18.571429],
#         [20.      ],
#         [21.428571],
#         [22.857143],
#         [24.285714],
#         [25.714286],
#         [27.142857],
#         [28.571429],
#         [30.      ]]),
#  array([ 81.937967,  71.725826,  74.353116,  80.140477,  88.08791 ,
#          98.195414, 110.463989, 124.891635, 141.478352, 160.22414 ,
#         181.129999, 204.195929, 229.42193 , 256.808002, 286.354145]))

# %%
#Splitting the data into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.4, random_state = 0)

# %%
print(X_train)
# Out:
# [[12.857143]
#  [28.571429]
#  [24.285714]
#  [20.      ]
#  [25.714286]
#  [14.285714]
#  [10.      ]
#  [17.142857]
#  [27.142857]]

# %%
print(X_test)
# Out:
# [[11.428571]
#  [18.571429]
#  [21.428571]
#  [22.857143]
#  [30.      ]
#  [15.714286]]

# %%
print(Y_train)
# Out:
# [ 74.353116 256.808002 181.129999 124.891635 204.195929  80.140477
#   81.937967  98.195414 229.42193 ]

# %%
print(Y_test)
# Out:
# [ 71.725826 110.463989 141.478352 160.22414  286.354145  88.08791 ]

# %%
#Training or Building Linear Regression Model on the whole dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Training or Building Polynomial Regression Model on the whole dataset
# Create PolynomialFeatures with degree 2 and transform the features
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X_train)

# %%
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, Y_train)
# Out:
# array([12.1401814])

# %%
prediction = lin_reg_2.predict(poly_reg.transform([[6.5]]))

# %%
# Visualize the Polynomial Regression results
plt.scatter(X_train, Y_train, color='green', label='Actual Data')
plt.plot(X_train, lin_reg_2.predict(X_poly), color='red', label='Polynomial Regression')
plt.title('Polynomial Regression')
plt.xlabel('Temperature')
plt.ylabel('Sales of Ice Cream')
plt.legend()
plt.show()

# %%
r = int(input("enter radius : "))
area = 3.14  * r * r
print("Area of Circle : ",area)
# Out:
# enter radius : 14
# Area of Circle :  615.44

# %%
a = input("Enter first name: ")
b = input("Enter first name: ")
print("Name: ",a , b)
# Out:
# Enter first name: Mihir
# Enter first name: Uikey
# Name:  Mihir  Uikey

# %%
r = 6
v = 4/3 * 3.14 * r * r * r
print("Radius of sphere : ",r, "\nVolume of Sphere :",v)
# Out:
# Radius of sphere :  6
# Volume of Sphere : 904.3199999999998

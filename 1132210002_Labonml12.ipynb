# %% [markdown]
# #Analysis of Wine Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
wine = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Lab on ml/Wine (1).csv')
wine
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
correlation_matrix = wine.corr()
correlation_matrix
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %%
X = wine.iloc[:,4:7].values
Y = wine.iloc[:,12].values

# %% [markdown]
# #Evaluation of regression models

# %% [markdown]
# #Training the dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train ,Y_test = train_test_split(X,Y,test_size =0.3, random_state=0)
X_test[1]
# Out:
# array([112.  ,   1.48,   1.36])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
Y_pred=regressor.predict(X_test)

# %%
#Residual plot
residuals =Y_test-Y_pred
#ploting the residual plot for wine dataset
plt.scatter(X_test[:,0], residuals, color = 'red')
plt.xlabel(' Magnesium, Total_Phenols, Flavanoids(independent variable)')
plt.ylabel('residuals(predicted profit- actual profit)')
plt.title('residual plot')
plt.show()

# %% [markdown]
# #Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test,Y_pred)
mae
# Out:
# 225.78936779049903

# %% [markdown]
# #Root Mean Square Error

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# 284.8779320991684

# %% [markdown]
# #Status Model

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
model.summary2().tables[0]
# Out:
#                      0                 1                    2          3
# 0               Model:               OLS      Adj. R-squared:      0.337
# 1  Dependent Variable:                 y                 AIC:  2483.6414
# 2                Date:  2023-10-09 16:38                 BIC:  2496.3686
# 3    No. Observations:               178      Log-Likelihood:    -1237.8
# 4            Df Model:                 3         F-statistic:      31.05
# 5        Df Residuals:               174  Prob (F-statistic):   4.00e-16
# 6           R-squared:             0.349               Scale:     65706.

# %% [markdown]
# #R_Squared and Adjusted R Square

# %%
# Linear regression model with one independent variable, observe R-Squared and Adj.R-squared
X = wine.iloc[:, 4].values
Y= wine.iloc[:,12].values
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary2().tables[0]
# Out:
#                      0                 1                    2          3
# 0               Model:               OLS      Adj. R-squared:      0.150
# 1  Dependent Variable:                 y                 AIC:  2526.0300
# 2                Date:  2023-10-09 16:40                 BIC:  2532.3936
# 3    No. Observations:               178      Log-Likelihood:    -1261.0
# 4            Df Model:                 1         F-statistic:      32.22
# 5        Df Residuals:               176  Prob (F-statistic):   5.59e-08
# 6           R-squared:             0.155               Scale:     84299.

# %%
# Linear regression model with one independent variable, observe R-Squared and Adj.R-squared
X = wine.iloc[:, 5].values
Y= wine.iloc[:,12].values
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary2().tables[0]
# Out:
#                      0                 1                    2          3
# 0               Model:               OLS      Adj. R-squared:      0.244
# 1  Dependent Variable:                 y                 AIC:  2505.1892
# 2                Date:  2023-10-09 16:41                 BIC:  2511.5527
# 3    No. Observations:               178      Log-Likelihood:    -1250.6
# 4            Df Model:                 1         F-statistic:      58.08
# 5        Df Residuals:               176  Prob (F-statistic):   1.50e-12
# 6           R-squared:             0.248               Scale:     74985.

# %%
# Linear regression model with one independent variable, observe R-Squared and Adj.R-Squared
X = wine.iloc[:, 6].values
Y= wine.iloc[:,12].values
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary2().tables[0]
# Out:
#                      0                 1                    2          3
# 0               Model:               OLS      Adj. R-squared:      0.240
# 1  Dependent Variable:                 y                 AIC:  2506.1081
# 2                Date:  2023-10-09 16:41                 BIC:  2512.4716
# 3    No. Observations:               178      Log-Likelihood:    -1251.1
# 4            Df Model:                 1         F-statistic:      56.87
# 5        Df Residuals:               176  Prob (F-statistic):   2.38e-12
# 6           R-squared:             0.244               Scale:     75373.
